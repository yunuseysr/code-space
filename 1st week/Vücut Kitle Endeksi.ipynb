# %%
boy = float(input("Boy Değerinizi Giriniz:"))
kilo = int(input("Kilo Değerinizi Giriniz:"))
x = boy**2
y = kilo/x
if y <= 18.5:
    print("Zayıfsınız.")
elif 18.5 < y <= 25:
    print("Normalsiniz.")
elif 25 < y <= 30:
    print("Kilolusunuz.")
elif 30 < y:
    print("Obezsiniz.”)
