# %%
import random


class Kullanicilar:
    a = 0

    def __init__(self):
        self.isim = ""
        self.soyisim = ""
        self.kullanici_id = ""

    @staticmethod
    def yas_hesapla():
        return 2022 - random.randint(1970, 1998)

# %%
import main


class Ogretmen:
    def __init__(self):
        self.e_mail = "yunusemreyasar@gmail.com"


class Ogrenci:
    def __init__(self):
        self.ogrenci_no = "180315059"


Kullanici1 = main.Kullanicilar()
Kullanici1.isim = "Talha"
Kullanici1.soyisim = "Çerçioğlu"
Kullanici1.kullanici_id = "180315059"
Kullanici2 = main.Kullanicilar()
Kullanici2.isim = "Yunus Emre"
Kullanici2.soyisim = "Yaşar"
Kullanici2.kullanici_id = "220154024"
print(Kullanici1.isim, Kullanici1.soyisim, "adlı öğrencinin kullanıcı numarası",Kullanici1.kullanici_id, "ve yaşı",
      Kullanici1.yas_hesapla())
print(Kullanici2.isim, Kullanici2.soyisim, "adlı öğretmenin kullanıcı numarası",Kullanici2.kullanici_id, "ve yaşı",
      Kullanici2.yas_hesapla())
