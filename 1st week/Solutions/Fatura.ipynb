# %%
import random

x = random.randint(0, 100)
y1 = random.randint(1, 30)
t1 = random.randint(1, 30)
y2 = random.randint(1, 12)
t2 = random.randint(y2, y2+1)
y3 = 22
z = random.uniform(0, 500)
print("Sayın", x, "nolu abonemiz", y1, '.', y2, '.', y3, '-', t1, '.', t2, '.', y3, 'dönemine ait faturanız', z,
      "TL'dir.")
print('Python Belediyesi.')
