# %%
t = input('Birinci Sayıyı Giriniz:')
t1 = int(t)
c = input('İkinci Sayıyı Giriniz:')
c1 = int(c)
x = t1 + c1
print('İki Sayının Ortalaması:', x//2, )
# Out:
# Birinci Sayıyı Giriniz:16
# İkinci Sayıyı Giriniz:15
# İki Sayının Ortalaması: 15
