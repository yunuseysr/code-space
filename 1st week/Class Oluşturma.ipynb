# %%
class User:
    name = ''
    surname = ''
    phone_no = ‘’

# %%
import main

user1 = main.User()
user1.name = "Talha"
user1.surname = "Çerçioğlu"
user1.phone_no = "0543*******"
user2 = main.User()
user2.name = "Yunus Emre"
user2.surname = "Yaşar"
user2.phone_no = "0551*******"
print(user1.name)
print(user1.surname)
print(user1.phone_no)
print(user2.name)
print(user2.surname)
print(user2.phone_no)
