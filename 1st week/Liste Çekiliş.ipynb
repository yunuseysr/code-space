# %%
import random
liste1 = ["Ahmet", "Mehmet", "Yunus", "Melisa", "Talha", "Sena", "Eda", "Selami", "Su", "Ekin"]
liste2 = []
x = liste1.pop(random.randint(0, 9))
y = liste1.pop(random.randint(0, 8))
z = liste1.pop(random.randint(0, 7))
liste2.append(x)
liste2.append(y)
liste2.append(z)
print("Çekilişin Kazananları:", liste2)
